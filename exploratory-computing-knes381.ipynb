# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/simulatedactivity-hr-data/jogging_hr.dat
# /kaggle/input/simulatedactivity-hr-data/sprint_hr.dat
# /kaggle/input/simulatedactivity-hr-data/walking_hr.dat
# /kaggle/input/ex4-data/hr_data.dat
# /kaggle/input/ex4-data/stages.dat
# /kaggle/input/ex4-data/vo2_data.dat

# %% [markdown]
# <img src="https://ucalgary.ca/themes/ucalgary/ucws_theme/images/UCalgary.svg" width="250" align="right">
#
# # Exploratory Computing with Python for Kinesiology
#
# ### Notebook 1: Basics and Plotting for Kinesiology Data
#
# ### First Python steps
# "Portable, powerful, and a breeze to use", Python is a popular, open-source programming language used for both scripting applications and standalone programs (see "Learning Python" by Mark Lutz, or [Automate the boring stuff](https://automatetheboringstuff.com/) by Al Sweigart). Python can be used to analyze all kinds of kinesiology data, from biomechanics to exercise physiology. For example, you can use Python as a calculator. Position your cursor in the code cell below and hit [shift][enter], or click the triangle to the left of the cell to "run" the cell, you can run any of the cells this way. The output of the first cell should be 12 😁 when run.
#
# Please note that the numbers in the brackets [ ] to the left of the code block will increment and change as you run the blocks, giving you a sequence of what has been run.
# This can be important as the variables you have assigned might change as you go through each cell, these cells, for the most part, were designed to be run in order...
# <div class="alert alert-block alert-info">
# <b>These examples are ment to be interactive, I encourge you to change the values in the code block, or add code to them, then rerun the block to see what and how things change.  Note, comment out the changed code when you do this so you can maintain the original.👍</b></div>
#
# *Created by Mark Bakker*
# *Redeveloped for Knesiology 381 by John Holash*

# %%
(6 * 6) # if you add a calculation below this how do you get both values to print?
# Out:
# 36

# %% [markdown]
# Note that the extra spaces are added to make the code more readable.
# `2 * 3` works just as well as `2*3`. And it is considered good style. Use the extra spaces in all your Notebooks.
#
# When you are programming, you want to store your values in variables (this means assigning a word to a numeric value) you will want to do this so that you can continue to call the variable name even if the value of it changes in your program.

# %%
a = 6
# Frist we store the value 6 in the variable "a"
b = 2
# then we store the value 2 in the variable "b"
# we can then do math with these variables..
a * b
# Out:
# 12

# %% [markdown]
# Both `a` and `b` are now variables. Each variable has a type. In this case, they are both integers (whole numbers). To write the value of a variable to the screen, use the `print` function (the last statement of a code cell is automatically printed to the screen if it is not stored in a variable, as was shown above). Note that multiplication of two integers results in an integer, but division of two integers results in a float (a number with decimal places).
# <div class="alert alert-block alert-info">
# <b>Tip:</b> variables are case sensitive a and A are two different variables.
# </div>

# %%
print(a)
print(b)
print(a * b)
print(a / b)
# Out:
# 6
# 2
# 12
# 3.0

# %% [markdown]
# You can add some text to the `print` function by putting the text string between quotes (either single or double quotes work as long as you use the same at the beginning and end), and separate the text string and the variable by a comma:

# %%
print('The strength training weight is', a,'kgs')
# Out:
# The strength training weight is 6 kgs

# %% [markdown]
# A variable can be raised to a power by using `**`
# (a hat `^`, as used in some other languages, doesn't work in python).

# %%
a ** b
# Out:
# 36

# %% [markdown]
# # Exercise 1a: First Python code for Kinesiology
# Compute the value of an athlete's maximum heart rate using the formula `HRmax = 220 - age` for ages 20, 35, and 65. Print the results to the screen.
#
# **A good way to accomplish this is to start by thinking step by step, like a reasoning LLM! Define the formula first, then define the first age value. Then calculate the maximum heart rate for that age. Print out the value for HRmax at the first age. Then change/reassign the value of age, calculate a new HRmax, and print it out. Repeat until you've covered all three ages.**
#
# The hyperlink below will take you to a version of the answer that I have created, but allow yourself to struggle a bit before checking the "answer". You won't break the internet if your code has a bug in it. You will just get a coding error when you try to run it.
#
# <div id="ex1a" name="ex1a">Exercise 1a</div>

# %%
# Your solution goes here

# %% [markdown]
# [Answer to Exercise 1a](#ex1aanswer)   You may need to scroll to the bottom where the answers are...

# %% [markdown]
# ## Division
# Division works as well, but often will convert two integers into a float value which can look messy

# %%
print('1/3 gives', 1 / 3)
# Out:
# 1/3 gives 0.3333333333333333

# %% [markdown]
# The above print statement looks pretty ugly in the output with many decimal places. A better and more readable way to print both text and the value of a variable to the screen is to use f-strings. F-strings allow you to insert the value of a variable anywhere in the text by surrounding it with braces `{}`. The entire text string needs to be between quotes and be preceded by the letter `f` (which stands for formatting...):

# %%
a = 1
b = 3
c = a / b
print(f'{a} divided by {b} gives {c}')
# Out:
# 1 divided by 3 gives 0.3333333333333333

# %% [markdown]
# The complete syntax between braces is `{variable:width.precision}`. When `width` and `precision` are not specified, Python will use all digits and figure out the width for you. If you want a floating point number with 3 decimals, you specify the number of digits, `3`, followed by the letter `f` for floating point. If you prefer exponent (scientific) notation, replace the `f` by an `e`. The text after the `#` is a comment in the code. Any text on the line after the `#` is ignored by Python, and is just there so you can understand what the code does.

# %%
print(f'{a} divided by {b} gives {c:.3f}')  # three decimal places
print(f'{a} divided by {b} gives {c:6.3f}')  # width 6 and three decimal places
print(f'{a} divided by {b} gives {c:.3e}')  # three decimal places scientific notation
# Out:
# 1 divided by 3 gives 0.333
# 1 divided by 3 gives  0.333
# 1 divided by 3 gives 3.333e-01

# %% [markdown]
# # Exercise 1b: First Python code using f-strings for Kinesiology
# Compute the body mass index (BMI) using the formula `BMI = weight / (height ** 2)`, where weight is in kg and height is in meters. Calculate BMI for weight = 70 kg and heights of 1.65 m, 1.78 m, and 1.95 m. Print the results to the screen using f-strings with 1 decimal place.
#
# <div id="ex1b" name="ex1b">Exercise 1b</div>

# %%
# Your solution goes here

# %% [markdown]
# Please attempt to answer the question before seeking the solution below.
# The first step would be to define (declare) your variables, then you would develop the equation, then print the answer. All of these steps have been accomplished above...
#
# [Answer to Exercise 1b](#ex1banswer)

# %% [markdown]
# ## More on variables
# Once you have created a variable in a Python session, it will remain in memory, so you can use it in other cells as well. For example, the variables `a` and `b`, which were defined two code cells above in this Notebook, still exist.

# %%
print(f'the value of a is: {a}')
print(f'the value of b is: {b}')
# Out:
# the value of a is: 1
# the value of b is: 3

# %% [markdown]
# The user (in this case: you!) decides the order in which code blocks are executed. For example, `In [6]` means that it is the sixth execution of a code block. If you change the same code block and run it again, it will get number 7. If you define the variable `a` in code block 7, it will overwrite the value of `a` defined in a previous code block.
#
# Variable names may be as long as you like (you gotta do the typing though). Selecting descriptive names aids in understanding the code. Variable names cannot have spaces, nor can they start with a number. And variable names are case sensitive. So the variable `myvariable` is not the same as the variable `MyVariable`. The name of a variable may be anything you want, except for reserved words in the Python language. For example, it is not possible to create a variable `for = 7`, as `for` is a reserved word. You will learn many of the reserved words when we continue; they are colored bold green when you type them in the Notebook.
#
# ## Basic plotting and a first array
# Plotting is not part of standard Python, but a nice package exists to create pretty graphics (and ugly ones, if you want). A package is a library of functions for a specific set of tasks. There are many Python packages and we will use several of them. The graphics package we use is called `matplotlib`. To be able to use the plotting functions in `matplotlib`, we have to import it. We will learn several different ways of importing packages. For now, we import the plotting part of `matplotlib` and call it `plt`. Before we import `matplotlib`, we tell the Jupyter Notebook to show any graphs inside this Notebook and not in a separate window using the `%matplotlib inline` command.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
print('The import was successful') #  This lets us know the code has run...
# Out:
# The import was successful

# %% [markdown]
# I have added the print line to the end to inform you that the import has successfully run, it is not needed but in interactive python the above command will complete without notification.
# Packages only have to be imported once in a Python session. After the above import statement, any plotting function may be called from any code cell as `plt.function`. For example:

# %%
plt.plot([1, 2, 4, 2]) # plot here is the function...

# %% [markdown]
# Let's try to plot oxygen consumption (VO₂) vs. exercise intensity for intensities ranging from 0% to 100% of maximum effort. We'll model this using the equation:
# `VO₂ = a * intensity² + b * intensity + c` with `a = 0.01`, `b = 0.3`, `c = 5`
#
# To do that, we need to evaluate VO₂ at a bunch of points. A sequence of values of the same type is called an array (for example an array of integers or floats). Array functionality is available in the package `numpy`. Let's import `numpy` and call it `np`, so that any function in the `numpy` package may be called as `np.function`.

# %%
# add numerical python to the project...
import numpy as np  # linear algebra
print('The import was successful')
# Out:
# The import was successful

# %% [markdown]
# To create an array `intensity` consisting of, for example, 5 equally spaced points between `0` and `100`, use the `linspace` command:

# %%
intensity = np.linspace(0, 100, 5)
print(intensity)
# Out:
# [  0.  25.  50.  75. 100.]

# %% [markdown]
# In the above cell, `intensity` is an array of 5 floats. If you type `np.linspace` and then an opening parenthesis like:
#
# `np.linspace(`
#
# and then hit [shift-tab] a little help box pops up to explain the input arguments of the function. When you click on the + sign, you can scroll through all the documentation of the `linspace` function. Click on the x sign to remove the help box. Let's plot VO₂ using 100 intensity values from 0% to 100%.

# %%
a = 0.01
b = 0.3
c = 5
intensity = np.linspace(0, 100, 100)
vo2 = a * intensity ** 2 + b * intensity + c  # Compute VO2 for all intensity values
plt.plot(intensity, vo2)

# %% [markdown]
# Note that *one hundred* `vo2` values are computed in the simple line `vo2 = a * intensity ** 2 + b * intensity + c`. Python treats arrays in the same fashion as it treats regular variables when you perform mathematical operations. The math is simply applied to every value in the array (and it runs much faster than when you would do every calculation separately).
#
# You may wonder what the statement like `[<matplotlib.lines.Line2D at 0x30990b0>]` is (the numbers above on your machine may look different). This is actually a handle to the line that is created with the last command in the code block (in this case `plt.plot(intensity, vo2)`). Remember: the result of the last line in a code cell is printed to the screen, unless it is stored in a variable. You can tell the Notebook not to print this to the screen by putting a semicolon after the last command in the code block (so type `plot(intensity, vo2);`).
#
# The `plot` function can take many arguments. Looking at the help box of the `plot` function, by typing `plt.plot(` and then shift-tab, gives you a lot of help. Typing `plt.plot?` gives a new scrollable subwindow at the bottom of the notebook, showing the documentation on `plot`. Click the x in the upper right hand corner to close the subwindow again.
#
# In short, `plot` can be used with one argument as `plot(y)`, which plots `y` values along the vertical axis and enumerates the horizontal axis starting at 0. `plot(x, y)` plots `y` vs `x`, and `plot(x, y, formatstring)` plots `y` vs `x` using colors and markers defined in `formatstring`, which can be a lot of things. It can be used to define the color, for example `'b'` for blue, `'r'` for red, and `'g'` for green. Or it can be used to define the linetype `'-'` for line, `'--'` for dashed, `':'` for dots. Or you can define markers, for example `'o'` for circles and `'s'` for squares. You can even combine them: `'r--'` gives a red dashed line, while `'go'` gives green circular markers.
#
# If that isn't enough, `plot` takes a large number of keyword arguments. A keyword argument is an optional argument that may be added to a function. The syntax is `function(keyword1=value1, keyword2=value2)`, etc. For example, to plot a line with width 6 (the default is 1), type:

# %%
plt.plot([1, 2, 3], [2, 4, 3], linewidth=6);

# %% [markdown]
# Keyword arguments should come after regular arguments. `plot(linewidth=6, [1, 2, 3], [2, 4, 3])` gives an error.
#
# Names may be added along the axes with the `xlabel` and `ylabel` functions, e.g., `plt.xlabel('this is the x-axis')`. Note that both functions take a string as argument. A title can be added to the figure with the `plt.title` command. Multiple curves can be added to the same figure by giving multiple plotting commands in the same code cell. They are automatically added to the same figure.
#
# ## New figure and figure size
#
# Whenever you give a plotting statement in a code cell, a figure with a default size is automatically created, and all subsequent plotting statements in the code cell are added to the same figure. If you want a different size of the figure, you can create a figure first with the desired figure size using the `plt.figure(figsize=(width, height))` syntax. Any subsequent plotting statement in the code cell is then added to the figure. You can even create a second figure (or third or fourth...).

# %%
plt.figure(figsize=(10, 3))
plt.plot([1, 2, 3], [2, 4, 3], linewidth=6)
plt.title('very wide figure')
plt.figure()  # new figure of default size
plt.plot([1, 2, 3], [1, 3, 1], 'r')
plt.title('second figure');

# %% [markdown]
# # Exercise 2: First Kinesiology Graph
# Plot a force-velocity curve for a muscle using the Hill equation: `F = (F_max * b) / (v + b)`, where F is force, v is velocity, F_max = 100 Newtons, and b = a constant = 30. Plot this for velocities ranging from 0 to 200 cm/s using a dashed red line. On the same figure, plot blue circles for velocities of 0, 50, 100, and 150 cm/s. Set the size of the markers to 10. Label the axes as 'Velocity (cm/s)' and 'Force (N)'. Add the title 'Force-Velocity Relationship of Muscle'.
#
# <div id="ex2" name="ex2">Exercise 2</div>

# %%
# Your solution goes here

# %% [markdown]
# [Answer to Exercise 2](#ex2answer)
#
# ## Style
#
# As was already mentioned above, good coding style is important. It makes the code easier to read so that it is much easier to find errors and bugs. For example, consider the code below, which recreates the graph we produced earlier (with a wider line), but now there are no additional spaces inserted:

# %%
a=0.01
b=0.3
c=5
intensity=np.linspace(0,100,100)
vo2=a*intensity**2+b*intensity+c#Compute VO2 for all intensity values
plt.plot(intensity,vo2,linewidth=3)

# %% [markdown]
# The code in the previous code cell is difficult to read. Good style includes at least the following:
# * spaces around every mathematical symbol (`=`, `+`, `-`, `*`, `/`), but not needed around `**`
# * spaces between arguments of a function
# * no spaces around an equal sign for a keyword argument (so `linewidth=3` is correct)
# * one space after every comma
# * one space after each `#`
# * two spaces before a `#` when it follows a Python statement
# * no space between the function name and the list of arguments. So `plt.plot(x, y)` is good style, and `plt.plot (x, y)` is not good style.
#
# These rules are (a very small part of) the official Python style guide called PEP8. When these rules are applied, the code is *much* easier to read, as you can see below:

# %%
a = 0.01
b = 0.3
c = 5
intensity = np.linspace(0, 100, 100)
vo2 = a * intensity**2 + b * intensity + c  # Compute VO2 for all intensity values
plt.plot(intensity, vo2, linewidth=3);

# %% [markdown]
# Use correct style in all other exercises and all Notebooks to come.
#
# # Exercise 2b. First graph revisited
# Go back to your Exercise 2 and apply correct style.
#
# ## Loading data files
#
# Numerical data can be loaded from a data file using the `loadtxt` function of `numpy`; i.e., the command is `np.loadtxt`. You need to make sure the file is in the same directory as your notebook, or provide the full path. The filename (or path plus filename) needs to be between quotes.
#
# # Exercise 3: Loading Exercise Data and Adding a Legend
# You are provided with data files containing heart rate measurements during different exercise protocols: walking (`walking_hr.dat`), jogging (`jogging_hr.dat`), and sprint intervals (`sprint_hr.dat`). Plot the heart rate for each activity against time (in minutes) all in a single graph. Add a legend using the function `plt.legend(['line1','line2'])`, etc., but with descriptive names. Find out about the `legend` command using `plt.legend?`. Place the legend in an appropriate spot (the upper left-hand corner may be nice, or let Python figure out the best place).
#
# The data files that you will need for the following exercises have been provided in the dataset "simulatedactivity-hr-data". If you click on one of the datasets you will be presented with the path to the dataset in a code window.
#
# Example:
# ```python
# # /kaggle/input/simulatedactivity-hr-data/jogging_hr.dat
# # Is the path to the jogging heart rate data file. To load this file into a dataframe (temporary data source) you would enter a line like this:
# jogging_hr = np.loadtxt('/kaggle/input/simulatedactivity-hr-data/jogging_hr.dat')
# # This will create the dataframe jogging_hr that will be active in your program.
# print(jogging_hr) # Will print out the values in this dataframe and `jogging_hr.shape` will tell you the shape of the data
# ```
# ## The code below will loading the jogging hr data from the data source on the right

# %%
jogging_hr = np.loadtxt('/kaggle/input/simulatedactivity-hr-data/jogging_hr.dat')
# practice loading other data by changing the dataframe name and datasource
print('dataframe loaded')
# Try to modify the line above by printing the dataframe or the dataframe.shape to see what happens
# Out:
# dataframe loaded

# %% [markdown]
# #### For this exercise below you can create a timeline variable (30 minutes of data) to plot against.
# #### This code should get you started.
# Example:
# ```python
# time = np.linspace(0, 30, 31)  # 0 to 30 minutes
# jogging_hr = np.loadtxt('/kaggle/input/simulatedactivity-hr-data/jogging_hr.dat')
# ```
# #### FYI These are the formulas I used to create the simulated data files
# ```python
# walking_hr = 80 + 20 * (1 - np.exp(-time/3))  # Gradual increase to steady state
# jogging_hr = 90 + 50 * (1 - np.exp(-time/2))  # Faster increase to higher steady state
# sprint_hr = 90 + 10 * time - 0.3 * time**2 + 30 * np.sin(time/3)  # Variable with intervals
# ```
# The datasets created from these formula are located on the right hand side in
# simulatedactivity-hr-data
#
# #### Plot all three datasets in this chart: jogging_hr, walking_hr, sprint_hr
# I will start you off with the basics... please include a label for the y axis and x axis, a legend and a title.
#
# To start you off...
# ```python
# plt.figure(figsize=(10, 6))
# plt.plot(time, jogging_hr);
# ```

# %%
# Your solution goes here

# %% [markdown]
# # Exercise 4: Subplots and Physiological Data Analysis
# Load the athlete's oxygen consumption (VO₂) and heart rate (HR) data during an incremental exercise test. Create one plot with two graphs above each other using the `subplot` command (use `plt.subplot?` to find out how). On the top graph, plot VO₂ and HR vs. time. Label the ticks on the horizontal axis as 'rest', '25%', '50%', '75%', '100%', rather than numbers. Use `plt.xticks?` to find out how. In the bottom graph, plot the oxygen pulse (VO₂/HR) vs. time. Add legends, axes labels, and a title.
#
# ```python
# # write some python code to load the hr_data
# # write some code ot load the vo2_data
#
# # Calculate oxygen pulse
# o2_pulse = vo2_data / hr_data
# ```

# %%
# Your solution goes here

# %% [markdown]
# ## Colors
# If you don't specify a color for a plotting statement, `matplotlib` will use its default colors. The first three default colors are special shades of blue, orange and green. The names of the default colors are a capital `C` followed by the number, starting with number `0`. For example:

# %%
plt.plot([0, 1], [0, 1], 'C0')
plt.plot([0, 1], [1, 2], 'C1')
plt.plot([0, 1], [2, 3], 'C2')
plt.legend(['default blue', 'default orange', 'default green']);

# %% [markdown]
# There are five different ways to specify your own colors in matplotlib plotting; you may read about them [here](http://matplotlib.org/examples/pylab_examples/color_demo.html). A useful way is to use the html color names. The html codes may be found, for example, [here](http://en.wikipedia.org/wiki/Web_colors).

# %%
color1 = 'fuchsia'
color2 = 'lime'
color3 = 'DodgerBlue'
plt.plot([0, 1], [0, 1], color1)
plt.plot([0, 1], [1, 2], color2)
plt.plot([0, 1], [2, 3], color3)
plt.legend([color1, color2, color3]);

# %% [markdown]
# The coolest (and nerdiest) way is probably to use the xkcd names, which need to be prefaced by the `xkcd:`. The xkcd list of color names is given by [xkcd](https://xkcd.com/color/rgb/) and includes favorites such as 'baby puke green' and a number of brown colors varying from `poo` to `poop brown` and `baby poop brown`. Try it out:

# %%
plt.plot([1, 2, 3], [4, 5, 2], 'xkcd:baby puke green');
plt.title('xkcd color baby puke green');

# %% [markdown]
# ## Gallery of graphs
# The plotting package `matplotlib` allows you to make very fancy graphs. Check out the <A href="http://matplotlib.org/gallery.html" target=_blank>matplotlib gallery</A> to get an overview of many of the options. The following exercises use several of the matplotlib options.
#
# # Exercise 5: Pie Chart of Energy Systems
# During exercise, the body uses different energy systems depending on the duration and intensity. Create a pie chart showing the contribution of different energy systems during a 400-meter sprint. The energy systems and their approximate contributions are: ATP-PC system (40%), Glycolytic system (55%), and Aerobic system (5%). Make a pie chart of these energy systems. Try some of the keyword arguments to make the plot look nice. Use the `colors` keyword in your pie chart to specify a sequence of colors.

# %%
# your solution goes here

# %% [markdown]
# ## Saving a file so you can use it later
# While it is great to make these fancy plots in python, you will likely need to output the files so that it is truely useful (include it in a report, paper, presentation...)
# To do this you will need to write the plot out to an image.  This can be a challange in python as when you plot a file out using the command plot as you did above, the image is written to the screen and saving it after this will produce an empty file.  To get around this issue you first have to save the plot using a command like this:
# ```python
# # Save the figure as a PNG file
# plt.savefig('energy_systems_400m_sprint.png', dpi=300, bbox_inches='tight')
#
# # Then if you want to display the plot as well you use this command
# plt.show()
# ```

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# # Answers for the exercises:
# <div id="ex1aanswer" name="ex1aanswer"><h2>Answer to Exercise 1a</h2></div>

# %%
age = 20
hrmax = 220 - age
print('Maximum heart rate at age', age, 'is', hrmax, 'bpm')

age = 35
hrmax = 220 - age
print('Maximum heart rate at age', age, 'is', hrmax, 'bpm')

age = 65
hrmax = 220 - age
print('Maximum heart rate at age', age, 'is', hrmax, 'bpm')
# Out:
# Maximum heart rate at age 20 is 200 bpm
# Maximum heart rate at age 35 is 185 bpm
# Maximum heart rate at age 65 is 155 bpm

# %% [markdown]
# [Back to Exercise 1a](#ex1a)  (You may need to scroll back up.😳 or use TOC to the right)
#
# <div id="ex1banswer" name="ex1banswer"><h2> Answer to Exercise 1b</h2></div>

# %%
# Define the variables
weight = 70  # kg

# Calculate BMI for different heights
height = 1.65  # meters
bmi = weight / (height ** 2)
print(f'BMI for height {height} m is {bmi:.1f} kg/m²')

height = 1.78  # meters
bmi = weight / (height ** 2)
print(f'BMI for height {height} m is {bmi:.1f} kg/m²')

height = 1.95  # meters
bmi = weight / (height ** 2)
print(f'BMI for height {height} m is {bmi:.1f} kg/m²')
# Out:
# BMI for height 1.65 m is 25.7 kg/m²
# BMI for height 1.78 m is 22.1 kg/m²
# BMI for height 1.95 m is 18.4 kg/m²

# %% [markdown]
# [Back to Exercise 1b](#ex1b) (Again you may need to scroll back up 🥲)
# <div id="ex2answer" name="ex2answer"><h2>Answer to Exercise 2</h2></div>

# %%
# Define parameters
f_max = 100  # Newtons
b = 30  # constant
velocity = np.linspace(0, 200, 100)  # cm/s

# Calculate force using Hill equation
force = (f_max * b) / (velocity + b)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(velocity, force, 'r--', linewidth=2)

# Add specific points
specific_velocities = [0, 50, 100, 150]
specific_forces = [(f_max * b) / (v + b) for v in specific_velocities]
plt.plot(specific_velocities, specific_forces, 'bo', markersize=10)

# Add labels and title
plt.xlabel('Velocity (cm/s)')
plt.ylabel('Force (N)')
plt.title('Force-Velocity Relationship of Muscle')

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# %% [markdown]
# [Back to Exercise 2](#ex2)
# <div id="ex3answer" name="ex3answer">,<h2>Answer to Exercise 3</h2></div>

# %%
# Create the dataframes from the datafiles
walking_hr = np.loadtxt('/kaggle/input/simulatedactivity-hr-data/walking_hr.dat')
jogging_hr = np.loadtxt('/kaggle/input/simulatedactivity-hr-data/jogging_hr.dat')
sprint_hr = np.loadtxt('/kaggle/input/simulatedactivity-hr-data/sprint_hr.dat')

time = np.linspace(0, 30, 31)  # 0 to 30 minutes

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(time, walking_hr, linewidth=2)
plt.plot(time, jogging_hr, linewidth=2)
plt.plot(time, sprint_hr, linewidth=2)

# Add labels and title
plt.xlabel('Time (minutes)')
plt.ylabel('Heart Rate (bpm)')
plt.title('Heart Rate Response During Different Exercise Protocols')

# Add legend
plt.legend(['Walking', 'Jogging', 'Sprint Intervals'], loc='best')

# Add grid
plt.grid(True, linestyle='--', alpha=0.5)

# %% [markdown]
# [Back to Exercise 3](#ex3)
# <div id="ex4answer" name="ex4answer"><h2>Answer to Exercise 4</h2></div>

# %%
# Sample data for VO2 and HR during incremental exercise test
#stages = np.array([0, 1, 2, 3, 4])
stages = np.loadtxt('/kaggle/input/ex4-data/stages.dat')
vo2_data = np.loadtxt('/kaggle/input/ex4-data/vo2_data.dat')
hr_data = np.loadtxt('/kaggle/input/ex4-data/hr_data.dat')
o2_pulse = vo2_data / hr_data

# Create figure with two subplots
plt.figure(figsize=(10, 8))

# Top subplot: VO2 and HR
plt.subplot(211)
plt.plot(stages, vo2_data, 'b-o', label='VO₂')
plt.plot(stages, hr_data, 'r-o', label='HR')
plt.ylabel('VO₂ (ml/kg/min) / HR (bpm)')
plt.title('Physiological Responses During Incremental Exercise Test')
plt.legend(loc='best')
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks([])  # Hide x-axis labels

# Bottom subplot: O2 Pulse
plt.subplot(212)
plt.plot(stages, o2_pulse, 'go-')
plt.xlabel('Exercise Intensity')
plt.ylabel('O₂ Pulse (ml/beat)')
plt.xticks(stages, ['Rest', '25%', '50%', '75%', '100%'])
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()

# %% [markdown]
# [Back to Exercise 4](#ex4)
#
# <div id="ex5answer" name="ex5answer"><h2>Answer to Exercise 5</h2></div>

# %%
# Energy system contributions during a 400m sprint
systems = ['ATP-PC System', 'Glycolytic System', 'Aerobic System']
contributions = [40, 55, 5]  # percentages

# Create pie chart
plt.figure(figsize=(10, 8))
plt.pie(contributions, labels=systems, 
        colors=['dodgerblue', 'firebrick', 'forestgreen'],
        autopct='%1.1f%%',  # Show percentages
        startangle=90,
        shadow=True,
        explode=(0.05, 0, 0))  # Slightly pull out the ATP-PC slice

plt.title('Energy System Contribution During 400m Sprint')
plt.axis('equal')

# Save the figure as a PNG file
plt.savefig('energy_systems_400m_sprint.png', dpi=300, bbox_inches='tight')

# If you want to display the plot as well
plt.show()
